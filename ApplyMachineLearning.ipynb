# %%
clear

# %%
# %run predict.py
# Out:
# Reading Data fromRNA_matrix_PCA50_toPredict.csv
# Reading Data Completed
# precision_micro: 0.9445802770986145
# precision_marco: 0.9506133755120221
# precision_weighted: 0.9450661944100477
# accuracy: 0.9445802770986145
# f1_micro: 0.9445802770986145
# f1_macro: 0.9520480430804832
# f1_weighted: 0.9446978471220614
# recall_micro: 0.9445802770986145
# recall_macro: 0.9538456130723892
# recall_weighted: 0.9445802770986145
# scores are [0.9506133755120221, 0.9445802770986145, 0.9520480430804832, 0.9538456130723892]

# %%
# %run predict-Lasso.py
# Out:
# Reading Data froms3://ee542group7lab/RNA_matrix_mixedType_ToPredict.csv
# Reading Data Completed
# selected features are [1586, 1870, 1916, 2493, 2693, 3041, 3638, 3671, 3978, 4609, 4815, 4957, 5726, 5813, 6306, 6367, 6445, 6682, 7244, 7568, 8154, 8498, 8741, 8767, 8801, 9280, 9706, 9876, 10323, 10963, 11959, 12016, 12155, 13610, 13874, 14402, 15347, 15930, 16321, 16356, 16851, 17547, 17778, 18941, 19042, 19731, 19834, 21040, 21635, 21696, 21807, 22640, 24315, 24762, 25003, 25091, 25581, 25670, 25972, 26397, 26782, 27442, 27852, 27915, 28226, 28545, 28926, 29428, 29857, 29921, 30684, 31017, 31292, 31772, 31790]
# precision_micro: 0.9755501222493888
# precision_marco: 0.9797400627260214
# precision_weighted: 0.9757218458556067
# accuracy: 0.9755501222493888
# f1_micro: 0.9755501222493888
# f1_macro: 0.9772350065103
# f1_weighted: 0.9755809071031176
# recall_micro: 0.9755501222493888
# recall_macro: 0.9748718102923545
# recall_weighted: 0.9755501222493888
# ...
